# %%
from category_encoders.one_hot import OneHotEncoder
from matplotlib import pyplot as plt
from math import floor

import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ---
# ## Média de Alunos por Turma ##

# %%
# lendo dataframe
atu_df = pd.read_excel('../dados/ATU_ESCOLAS_2019.xlsx', header=8, usecols=[5, 25], names=['cod inep', 'media alunos turma'])

# removendo todas escolas que não possuem ensino medio
atu_df = atu_df.replace('--',np.nan)
atu_df.dropna(inplace=True)

# configurando tipo correto para os dados
atu_df['cod inep'] = atu_df['cod inep'].astype('int64')
atu_df['media alunos turma'] = atu_df['media alunos turma'].astype('float64')

# configurando codigo da escola como indice
atu_df.set_index('cod inep', drop=True, inplace=True)

print(atu_df.head())

print('-------------------------------------------')
print(atu_df.info())

print('-------------------------------------------')
print(atu_df.describe())
# Out:
#           media alunos turma
# cod inep
# 11024968                28.1
# 11025638                15.3
# 11037962                 8.0
# 11038373                 7.0
# 11046252                 8.0
# -------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28836 entries, 11024968 to 53086007
# Data columns (total 1 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   media alunos turma  28836 non-null  float64
# dtypes: float64(1)
# memory usage: 450.6 KB
# None
# -------------------------------------------
#        media alunos turma
# count        28836.000000
# mean            26.648769
# std              9.211435
# min              1.000000
# 25%             21.000000
# 50%             27.700000
# 75%             33.000000
# max            231.300000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_figheight(10)
fig.set_figwidth(25)
fig.suptitle('Média de alunos por turma')

ax1.boxplot(atu_df['media alunos turma'])
ax2.hist(atu_df['media alunos turma'],bins=20)

plt.show()

# %%
atu_df['media alunos turma'].sort_values(ascending=False)
# Out:
# cod inep
# 41618947    231.3
# 41133501    144.7
# 41154231    129.3
# 33177996    122.7
# 41387945    113.3
#             ...
# 51065215      1.0
# 14001497      1.0
# 33106029      1.0
# 11049065      1.0
# 29692628      1.0
# Name: media alunos turma, Length: 28836, dtype: float64

# %% [markdown]
# ---
# ## Média de Horas-Aula diárias ##

# %%
# lendo dataframe
had_df = pd.read_excel('../dados/HAD_ESCOLAS_2019.xlsx', header=8, usecols=[5, 24], names=['cod inep', 'media hora-aula diaria'])

# removendo escolas que não possuem ensino medio
had_df = had_df.replace('--',np.nan)
had_df.dropna(inplace=True)

# configurando tipo correto para os dados
had_df['cod inep'] = had_df['cod inep'].astype('int64')
had_df['media hora-aula diaria'] = had_df['media hora-aula diaria'].astype('float64')

# configurando codigo da escola como indice
had_df.set_index('cod inep', drop=True, inplace=True)

print(had_df.head())

print('-------------------------------------------')
print(had_df.info())

print('-------------------------------------------')
print(had_df.describe())
# Out:
#           media hora-aula diaria
# cod inep
# 11024968                     9.5
# 11025638                     3.9
# 11037962                     4.0
# 11038373                     4.0
# 11046252                     4.0
# -------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28833 entries, 11024968 to 53086007
# Data columns (total 1 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   media hora-aula diaria  28833 non-null  float64
# dtypes: float64(1)
# memory usage: 450.5 KB
# None
# -------------------------------------------
#        media hora-aula diaria
# count            28833.000000
# mean                 5.199327
# std                  1.441634
# min                  1.700000
# 25%                  4.300000
# 50%                  5.000000
# 75%                  5.300000
# max                 16.500000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_figheight(10)
fig.set_figwidth(25)
fig.suptitle('Média de horas-aula por dia')
ax1.boxplot(had_df['media hora-aula diaria'])
ax2.hist(had_df['media hora-aula diaria'],bins=20)
plt.show()

# %%
had_df['media hora-aula diaria'].sort_values(ascending=False)
# Out:
# cod inep
# 15156907    16.5
# 31343064    16.0
# 17040124    16.0
# 29427223    15.5
# 29204313    15.5
#             ...
# 31005371     2.7
# 25128809     2.6
# 21279586     2.5
# 41093690     2.0
# 35985673     1.7
# Name: media hora-aula diaria, Length: 28833, dtype: float64

# %% [markdown]
# ---
# ## Taxa Distorção Idade ##

# %%
# lendo dataframe
tdi_df = pd.read_excel('../dados/TDI_ESCOLAS_2019.xlsx', header=8, usecols=[5, 21], names=['cod inep', 'taxa distorcao idade serie'])

# removendo escolas que não possuem ensino medio
tdi_df = tdi_df.replace('--',np.nan)
tdi_df.dropna(inplace=True)

# configurando tipo correto para os dados
tdi_df['cod inep'] = tdi_df['cod inep'].astype('int64')
tdi_df['taxa distorcao idade serie'] = tdi_df['taxa distorcao idade serie'].astype('float64')

# configurando codigo da escola como indice
tdi_df.set_index('cod inep', drop=True, inplace=True)

print(tdi_df.head())

print('-------------------------------------------')
print(tdi_df.info())

print('-------------------------------------------')
print(tdi_df.describe())
# Out:
#           taxa distorcao idade serie
# cod inep
# 11024968                         9.1
# 11025638                        28.4
# 11037962                       100.0
# 11038373                        95.2
# 11046252                        75.0
# -------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28595 entries, 11024968 to 53086007
# Data columns (total 1 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   taxa distorcao idade serie  28595 non-null  float64
# dtypes: float64(1)
# memory usage: 446.8 KB
# None
# -------------------------------------------
#        taxa distorcao idade serie
# count                28595.000000
# mean                    23.101553
# std                     18.829977
# min                      0.000000
# 25%                      8.200000
# 50%                     18.700000
# 75%                     33.400000
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_figheight(10)
fig.set_figwidth(25)
fig.suptitle('Taxa de distorção da idade por série')
ax1.boxplot(tdi_df['taxa distorcao idade serie'])
ax2.hist(tdi_df['taxa distorcao idade serie'],bins=20)
plt.show()

# %% [markdown]
# ---
# ## Índice de Esforço Docente ##

# %%
# lendo dataframe
ied_df = pd.read_excel('../dados/IED_ESCOLAS_2019.xlsx', header=10, usecols=[5, 27, 28, 29, 30, 31, 32],
    names=['cod inep','perc doc1','perc doc2','perc doc3','perc doc4','perc doc5','perc doc6'])

# removendo escolas que não possuem ensino medio
ied_df = ied_df.replace('--',np.nan)
ied_df.dropna(inplace=True)

# configurando tipo correto para os dados
ied_df['cod inep'] = ied_df['cod inep'].astype('int64')
ied_df['perc doc1'] = ied_df['perc doc1'].astype('float64')
ied_df['perc doc2'] = ied_df['perc doc2'].astype('float64')
ied_df['perc doc3'] = ied_df['perc doc3'].astype('float64')
ied_df['perc doc4'] = ied_df['perc doc4'].astype('float64')
ied_df['perc doc5'] = ied_df['perc doc5'].astype('float64')
ied_df['perc doc6'] = ied_df['perc doc6'].astype('float64')

# configurando codigo da escola como indice
ied_df.set_index('cod inep', drop=True, inplace=True)

print(ied_df.head())

print('-------------------------------------------')
print(ied_df.info())

print('-------------------------------------------')
print(ied_df.describe())
# Out:
#           perc doc1  perc doc2  perc doc3  perc doc4  perc doc5  perc doc6
# cod inep
# 11024968        0.0       33.3       46.7       13.3        6.7        0.0
# 11025638        0.0        0.0        0.0       43.9       34.1       22.0
# 11037962        6.1        0.0        0.0       18.8       68.8        6.3
# 11038373       11.8        0.0        0.0       17.6       64.7        5.9
# 11046252       11.8        0.0        0.0       17.6       64.7        5.9
# -------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28860 entries, 11024968 to 53086007
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   perc doc1  28860 non-null  float64
#  1   perc doc2  28860 non-null  float64
#  2   perc doc3  28860 non-null  float64
#  3   perc doc4  28860 non-null  float64
#  4   perc doc5  28860 non-null  float64
#  5   perc doc6  28860 non-null  float64
# dtypes: float64(6)
# ...

# %%
fig, axs = plt.subplots(3, 2)
fig.set_figheight(10)
fig.set_figwidth(25)
fig.suptitle('Percentual de Índice de Esforço Docente')
axs[0,0].set_title('% Tipo 1')
axs[0,1].set_title('% Tipo 2')
axs[1,0].set_title('% Tipo 3')
axs[1,1].set_title('% Tipo 4')
axs[2,0].set_title('% Tipo 5')
axs[2,1].set_title('% Tipo 6')

axs[0,0].hist(ied_df['perc doc1'],bins=20)
axs[0,1].hist(ied_df['perc doc2'],bins=20)
axs[1,0].hist(ied_df['perc doc3'],bins=20)
axs[1,1].hist(ied_df['perc doc4'],bins=20)
axs[2,0].hist(ied_df['perc doc5'],bins=20)
axs[2,1].hist(ied_df['perc doc6'],bins=20)

plt.show()

# %% [markdown]
# ---
# ## Taxa de Rendimento Escolar ##

# %%
# lendo dataframe
tre_df = pd.read_excel('../dados/tx_rend_escolas_2019.xlsx', header=8, usecols=[5, 21, 39, 57], names=['cod inep', 'perc aprovado', 'perc reprovado', 'perc evasao'])

# removendo escolas que não possuem ensino medio
tre_df = tre_df.replace('--',np.nan)
tre_df.dropna(inplace=True)

# configurando tipo correto para os dados
tre_df['cod inep'] = tre_df['cod inep'].astype('int64')
tre_df['perc aprovado'] = tre_df['perc aprovado'].astype('float64')
tre_df['perc reprovado'] = tre_df['perc reprovado'].astype('float64')
tre_df['perc evasao'] = tre_df['perc evasao'].astype('float64')

# configurando codigo da escola como indice
tre_df.set_index('cod inep', drop=True, inplace=True)

print(tre_df.head())

print('-------------------------------------------')
print(tre_df.info())

print('-------------------------------------------')
print(tre_df.describe())
# Out:
#           perc aprovado  perc reprovado  perc evasao
# cod inep
# 11024968           97.7             2.3          0.0
# 11025638           91.4             0.5          8.1
# 11037962          100.0             0.0          0.0
# 11038373           76.2            23.8          0.0
# 11046252           83.3            16.7          0.0
# -------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28642 entries, 11024968 to 53086007
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   perc aprovado   28642 non-null  float64
#  1   perc reprovado  28642 non-null  float64
#  2   perc evasao     28642 non-null  float64
# dtypes: float64(3)
# memory usage: 895.1 KB
# None
# -------------------------------------------
#        perc aprovado  perc reprovado   perc evasao
# count   28642.000000    28642.000000  28642.000000
# mean       88.954280        7.298048      3.747671
# ...

# %%
fig, axs = plt.subplots(1, 2)
fig.set_figheight(5)
fig.set_figwidth(25)
fig.suptitle('Taxa de redimento escolar - Aprovação')

axs[0].boxplot(tre_df['perc aprovado'])
axs[1].hist(tre_df['perc aprovado'],bins=20)
plt.show()

# %%
fig, axs = plt.subplots(1, 2)
fig.set_figheight(5)
fig.set_figwidth(25)
fig.suptitle('Taxa de redimento escolar - Reprovação')

axs[0].boxplot(tre_df['perc reprovado'])
axs[1].hist(tre_df['perc reprovado'],bins=20)
plt.show()

# %%
fig, axs = plt.subplots(1, 2)
fig.set_figheight(5)
fig.set_figwidth(25)
fig.suptitle('Taxa de redimento escolar - Evasão')

axs[0].boxplot(tre_df['perc evasao'])
axs[1].hist(tre_df['perc evasao'],bins=20)
plt.show()

# %% [markdown]
# ---
# ## Índice de Nível SocioEconomico ##

# %%
# lendo dataframe
inse_df = pd.read_excel('../dados/INSE_2019_ESCOLAS.xlsx', header=0, usecols=[0, 10, 11], names=['cod inep', 'valor inse', 'class inse'])

# configurando tipo correto para os dados
inse_df['cod inep'] = inse_df['cod inep'].astype('int64')
inse_df['valor inse'] = inse_df['valor inse'].astype('float64')
inse_df['class inse'] = inse_df['class inse'].astype('category')

# configurando codigo da escola como indice
inse_df.set_index('cod inep', drop=True, inplace=True)

print(inse_df.head())

print('-------------------------------------------')
print(inse_df.info())

print('-------------------------------------------')
print(inse_df.describe())
# Out:
#           valor inse class inse
# cod inep
# 11024666        4.54   Nível IV
# 11024682        4.96   Nível IV
# 11024828        4.87   Nível IV
# 11024968        4.78   Nível IV
# 11025077        4.60   Nível IV
# -------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68868 entries, 11024666 to 53068238
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   valor inse  68868 non-null  float64
#  1   class inse  68868 non-null  category
# dtypes: category(1), float64(1)
# memory usage: 1.1 MB
# None
# -------------------------------------------
#          valor inse
# count  68868.000000
# mean       4.700523
# std        0.568479
# min        2.470000
# 25%        4.270000
# 50%        4.730000
# 75%        5.140000
# max        6.590000

# %%
fig, axs = plt.subplots(1, 2)
fig.set_figheight(10)
fig.set_figwidth(25)
fig.suptitle('Índice Socioeconômico')

sns.boxplot(ax=axs[0], data=inse_df, y='valor inse', x='class inse')
sns.histplot(ax=axs[1], data=inse_df, x='valor inse', hue='class inse',bins=25)

plt.show()

# %% [markdown]
# ---
# ## Educação Básica ##

# %%
cols_in = [
    'CO_REGIAO', 'CO_UF', 'CO_MUNICIPIO', 'CO_MESORREGIAO', 'CO_MICRORREGIAO',
    'CO_DISTRITO', 'CO_ENTIDADE', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA',
    'TP_LOCALIZACAO', 'TP_LOCALIZACAO_DIFERENCIADA', 'TP_SITUACAO_FUNCIONAMENTO',
    'IN_VINCULO_SECRETARIA_EDUCACAO', 'IN_VINCULO_SEGURANCA_PUBLICA', 'IN_VINCULO_SECRETARIA_SAUDE',
    'IN_VINCULO_OUTRO_ORGAO', 'IN_CONVENIADA_PP', 'TP_CONVENIO_PODER_PUBLICO',
    'IN_MANT_ESCOLA_PRIVADA_EMP', 'IN_MANT_ESCOLA_PRIVADA_ONG', 'IN_MANT_ESCOLA_PRIVADA_OSCIP',
    'IN_MANT_ESCOLA_PRIV_ONG_OSCIP', 'IN_MANT_ESCOLA_PRIVADA_SIND', 'IN_MANT_ESCOLA_PRIVADA_SIST_S',
    'IN_MANT_ESCOLA_PRIVADA_S_FINS', 'IN_LOCAL_FUNC_PREDIO_ESCOLAR', 'TP_OCUPACAO_PREDIO_ESCOLAR',
    'IN_LOCAL_FUNC_SOCIOEDUCATIVO', 'IN_LOCAL_FUNC_UNID_PRISIONAL', 'IN_LOCAL_FUNC_PRISIONAL_SOCIO',
    'IN_LOCAL_FUNC_GALPAO', 'TP_OCUPACAO_GALPAO', 'IN_LOCAL_FUNC_SALAS_OUTRA_ESC', 'IN_LOCAL_FUNC_OUTROS',
    'IN_PREDIO_COMPARTILHADO', 'IN_AGUA_POTAVEL', 'IN_ENERGIA_REDE_PUBLICA', 'IN_ESGOTO_REDE_PUBLICA',
    'IN_ALMOXARIFADO', 'IN_AREA_VERDE', 'IN_AUDITORIO', 'IN_BANHEIRO', 'IN_BANHEIRO_FUNCIONARIOS',
    'IN_BANHEIRO_CHUVEIRO', 'IN_BIBLIOTECA', 'IN_BIBLIOTECA_SALA_LEITURA', 'IN_COZINHA', 'IN_DORMITORIO_ALUNO',
    'IN_DORMITORIO_PROFESSOR', 'IN_LABORATORIO_CIENCIAS', 'IN_LABORATORIO_INFORMATICA', 'IN_PARQUE_INFANTIL',
    'IN_PISCINA', 'IN_QUADRA_ESPORTES', 'IN_REFEITORIO', 'IN_SALA_ATELIE_ARTES', 'IN_SALA_MUSICA_CORAL',
    'IN_SALA_ESTUDIO_DANCA', 'IN_SALA_MULTIUSO', 'IN_SALA_DIRETORIA', 'IN_SALA_LEITURA', 'IN_SALA_PROFESSOR',
    'IN_SALA_REPOUSO_ALUNO', 'IN_SECRETARIA', 'IN_TERREIRAO', 'IN_VIVEIRO', 'IN_DEPENDENCIAS_OUTRAS',
    'QT_SALAS_UTILIZADAS', 'QT_SALAS_UTILIZA_CLIMATIZADAS', 'IN_EQUIP_SCANNER', 'QT_EQUIP_DVD', 'QT_EQUIP_SOM',
    'QT_EQUIP_TV', 'QT_EQUIP_LOUSA_DIGITAL', 'QT_EQUIP_MULTIMIDIA', 'QT_DESKTOP_ALUNO', 'QT_COMP_PORTATIL_ALUNO',
    'QT_TABLET_ALUNO', 'IN_INTERNET', 'IN_INTERNET_ALUNOS', 'IN_INTERNET_ADMINISTRATIVO',
    'IN_INTERNET_APRENDIZAGEM', 'IN_INTERNET_COMUNIDADE', 'IN_ACESSO_INTERNET_COMPUTADOR',
    'IN_ACES_INTERNET_DISP_PESSOAIS', 'TP_REDE_LOCAL', 'IN_BANDA_LARGA', 'QT_PROF_ADMINISTRATIVOS',
    'QT_PROF_SERVICOS_GERAIS', 'QT_PROF_BIBLIOTECARIO', 'QT_PROF_SAUDE', 'QT_PROF_COORDENADOR',
    'QT_PROF_FONAUDIOLOGO', 'QT_PROF_NUTRICIONISTA', 'QT_PROF_PSICOLOGO', 'QT_PROF_ALIMENTACAO',
    'QT_PROF_PEDAGOGIA', 'QT_PROF_SECRETARIO', 'QT_PROF_SEGURANCA', 'QT_PROF_MONITORES', 'IN_ALIMENTACAO',
    'IN_SERIE_ANO', 'IN_PERIODOS_SEMESTRAIS', 'IN_FUNDAMENTAL_CICLOS', 'IN_GRUPOS_NAO_SERIADOS', 'IN_MODULOS',
    'IN_FORMACAO_ALTERNANCIA', 'IN_MATERIAL_PED_MULTIMIDIA', 'IN_MATERIAL_PED_INFANTIL', 'IN_MATERIAL_PED_CIENTIFICO',
    'IN_MATERIAL_PED_DIFUSAO', 'IN_MATERIAL_PED_MUSICAL', 'IN_MATERIAL_PED_JOGOS', 'IN_MATERIAL_PED_ARTISTICAS',
    'IN_MATERIAL_PED_DESPORTIVA', 'IN_MATERIAL_PED_INDIGENA', 'IN_MATERIAL_PED_ETNICO', 'IN_MATERIAL_PED_CAMPO',
    'IN_EDUCACAO_INDIGENA', 'TP_INDIGENA_LINGUA', 'IN_EXAME_SELECAO', 'IN_RESERVA_PPI', 'IN_RESERVA_RENDA',
    'IN_RESERVA_PUBLICA', 'IN_RESERVA_PCD', 'IN_RESERVA_OUTROS', 'IN_RESERVA_NENHUMA', 'IN_REDES_SOCIAIS', 
    'IN_ESPACO_ATIVIDADE', 'IN_ESPACO_EQUIPAMENTO', 'IN_ORGAO_ASS_PAIS', 'IN_ORGAO_ASS_PAIS_MESTRES',
    'IN_ORGAO_CONSELHO_ESCOLAR', 'IN_ORGAO_GREMIO_ESTUDANTIL', 'IN_ORGAO_OUTROS', 'IN_ORGAO_NENHUM',
    'IN_DIURNO', 'IN_NOTURNO', 'IN_EAD', 'IN_BAS', 'IN_INF', 'IN_INF_CRE', 'IN_INF_PRE', 'IN_FUND',
    'IN_FUND_AI', 'IN_FUND_AF', 'IN_MED', 'IN_PROF', 'IN_PROF_TEC', 'IN_EJA', 'IN_EJA_FUND', 'IN_EJA_MED',
    'IN_ESP', 'IN_ESP_CC', 'IN_ESP_CE', 'QT_DOC_MED', 'QT_DOC_PROF', 'QT_DOC_PROF_TEC', 'QT_DOC_EJA',
    'QT_DOC_EJA_FUND', 'QT_DOC_EJA_MED', 'QT_DOC_ESP', 'QT_DOC_ESP_CC', 'QT_DOC_ESP_CE', 'QT_TUR_MED',
    'QT_TUR_PROF', 'QT_TUR_PROF_TEC', 'QT_TUR_EJA', 'QT_TUR_EJA_FUND', 'QT_TUR_EJA_MED', 'QT_TUR_ESP',
    'QT_TUR_ESP_CC', 'QT_TUR_ESP_CE', 'QT_MAT_BAS', 'QT_MAT_MED'
]

print(len(cols_in))
# Out:
# 176

# %%
def preencher_limitantes(instancia):
    instancia['qt_equip_dvd'] = instancia['qt_equip_dvd'] if instancia['qt_equip_dvd'] != 88888 else floor(0.75*instancia['qt_salas_utilizadas'])
    instancia['qt_equip_som'] = instancia['qt_equip_som'] if instancia['qt_equip_som'] != 88888 else floor(0.75*instancia['qt_salas_utilizadas'])
    instancia['qt_equip_tv'] = instancia['qt_equip_tv'] if instancia['qt_equip_tv'] != 88888 else floor(0.75*instancia['qt_salas_utilizadas'])
    instancia['qt_equip_lousa_digital'] = instancia['qt_equip_lousa_digital'] if instancia['qt_equip_lousa_digital'] != 88888 else floor(0.75*instancia['qt_salas_utilizadas'])
    instancia['qt_equip_multimidia'] = instancia['qt_equip_multimidia'] if instancia['qt_equip_multimidia'] != 88888 else floor(0.75*instancia['qt_salas_utilizadas'])
    instancia['qt_desktop_aluno'] = instancia['qt_desktop_aluno'] if instancia['qt_desktop_aluno'] != 88888 else floor(0.75*instancia['qt_salas_utilizadas'])
    instancia['qt_comp_portatil_aluno'] = instancia['qt_comp_portatil_aluno'] if instancia['qt_comp_portatil_aluno'] != 88888 else floor(0.75*instancia['qt_salas_utilizadas'])
    instancia['qt_tablet_aluno'] = instancia['qt_tablet_aluno'] if instancia['qt_tablet_aluno'] != 88888 else floor(0.75*instancia['qt_salas_utilizadas'])

    instancia['qt_prof_administrativos'] = instancia['qt_prof_administrativos'] if instancia['qt_prof_administrativos'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_servicos_gerais'] = instancia['qt_prof_servicos_gerais'] if instancia['qt_prof_servicos_gerais'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_bibliotecario'] = instancia['qt_prof_bibliotecario'] if instancia['qt_prof_bibliotecario'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_saude'] = instancia['qt_prof_saude'] if instancia['qt_prof_saude'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_coordenador'] = instancia['qt_prof_coordenador'] if instancia['qt_prof_coordenador'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_fonaudiologo'] = instancia['qt_prof_fonaudiologo'] if instancia['qt_prof_fonaudiologo'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_nutricionista'] = instancia['qt_prof_nutricionista'] if instancia['qt_prof_nutricionista'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_psicologo'] = instancia['qt_prof_psicologo'] if instancia['qt_prof_psicologo'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_alimentacao'] = instancia['qt_prof_alimentacao'] if instancia['qt_prof_alimentacao'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_pedagogia'] = instancia['qt_prof_pedagogia'] if instancia['qt_prof_pedagogia'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_secretario'] = instancia['qt_prof_secretario'] if instancia['qt_prof_secretario'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_seguranca'] = instancia['qt_prof_seguranca'] if instancia['qt_prof_seguranca'] != 88888 else 3*instancia['qt_mat_bas']
    instancia['qt_prof_monitores'] = instancia['qt_prof_monitores'] if instancia['qt_prof_monitores'] != 88888 else 3*instancia['qt_mat_bas']
    
    return instancia

# %%
yn = {np.nan:'nao', 0:'nao', 1:'sim'}

# lendo dataframe
eb = pd.read_csv('../dados/microdados_ed_basica_2019.csv', sep=';', header=0, encoding='latin-1', usecols=cols_in)
eb.columns = [col.lower().strip() for col in eb.columns]

# filtrar escolas ativas
eb = eb[eb['tp_situacao_funcionamento'] == 1]

# filtrar outlier
eb = eb[eb['qt_salas_utilizadas'] < 1000]

# ajustando variaveis inteiras
eb['qt_tur_med'] = eb['qt_tur_med'].replace({np.nan:0}).astype('int64')
eb['qt_tur_prof_tec'] = eb['qt_tur_prof_tec'].replace({np.nan:0}).astype('int64')
eb['qt_tur_eja'] = eb['qt_tur_eja'].replace({np.nan:0}).astype('int64')
eb['qt_tur_eja_fund'] = eb['qt_tur_eja_fund'].replace({np.nan:0}).astype('int64')
eb['qt_tur_eja_med'] = eb['qt_tur_eja_med'].replace({np.nan:0}).astype('int64')
eb['qt_tur_esp'] = eb['qt_tur_esp'].replace({np.nan:0}).astype('int64')
eb['qt_tur_esp_cc'] = eb['qt_tur_esp_cc'].replace({np.nan:0}).astype('int64')
eb['qt_tur_esp_ce'] = eb['qt_tur_esp_ce'].replace({np.nan:0}).astype('int64')
eb['qt_tur_prof'] = eb['qt_tur_prof'].replace({np.nan:0}).astype('int64')
eb['qt_doc_med'] = eb['qt_doc_med'].replace({np.nan:0}).astype('int64')
eb['qt_doc_eja_fund'] = eb['qt_doc_eja_fund'].replace({np.nan:0}).astype('int64')
eb['qt_doc_eja_med'] = eb['qt_doc_eja_med'].replace({np.nan:0}).astype('int64')
eb['qt_doc_prof'] = eb['qt_doc_prof'].replace({np.nan:0}).astype('int64')
eb['qt_doc_prof_tec'] = eb['qt_doc_prof_tec'].replace({np.nan:0}).astype('int64')
eb['qt_doc_eja'] = eb['qt_doc_eja'].replace({np.nan:0}).astype('int64')
eb['qt_doc_esp_ce'] = eb['qt_doc_esp_ce'].replace({np.nan:0}).astype('int64')
eb['qt_doc_esp_cc'] = eb['qt_doc_esp_cc'].replace({np.nan:0}).astype('int64')
eb['qt_doc_esp'] = eb['qt_doc_esp'].replace({np.nan:0}).astype('int64')
eb['qt_mat_bas'] = eb['qt_mat_bas'].replace({np.nan:0}).astype('int64')
eb['qt_mat_med'] = eb['qt_mat_med'].replace({np.nan:0}).astype('int64')
eb['qt_salas_utilizadas'] = eb['qt_salas_utilizadas'].astype('int64')
eb['qt_salas_utiliza_climatizadas'] = eb['qt_salas_utiliza_climatizadas'].astype('int64')
eb['qt_equip_dvd'] = eb['qt_equip_dvd'].astype('int64')
eb['qt_equip_som'] = eb['qt_equip_som'].astype('int64')
eb['qt_equip_tv'] = eb['qt_equip_tv'].astype('int64')
eb['qt_equip_lousa_digital'] = eb['qt_equip_lousa_digital'].astype('int64')
eb['qt_equip_multimidia'] = eb['qt_equip_multimidia'].astype('int64')
eb['qt_desktop_aluno'] = eb['qt_desktop_aluno'].astype('int64')
eb['qt_comp_portatil_aluno'] = eb['qt_comp_portatil_aluno'].astype('int64')
eb['qt_tablet_aluno'] = eb['qt_tablet_aluno'].astype('int64')
eb['qt_prof_administrativos'] = eb['qt_prof_administrativos'].astype('int64')
eb['qt_prof_servicos_gerais'] = eb['qt_prof_servicos_gerais'].astype('int64')
eb['qt_prof_bibliotecario'] = eb['qt_prof_bibliotecario'].astype('int64')
eb['qt_prof_saude'] = eb['qt_prof_saude'].astype('int64')
eb['qt_prof_coordenador'] = eb['qt_prof_coordenador'].astype('int64')
eb['qt_prof_fonaudiologo'] = eb['qt_prof_fonaudiologo'].astype('int64')
eb['qt_prof_nutricionista'] = eb['qt_prof_nutricionista'].astype('int64')
eb['qt_prof_psicologo'] = eb['qt_prof_psicologo'].astype('int64')
eb['qt_prof_alimentacao'] = eb['qt_prof_alimentacao'].astype('int64')
eb['qt_prof_pedagogia'] = eb['qt_prof_pedagogia'].astype('int64')
eb['qt_prof_secretario'] = eb['qt_prof_secretario'].astype('int64')
eb['qt_prof_seguranca'] = eb['qt_prof_seguranca'].astype('int64')
eb['qt_prof_monitores'] = eb['qt_prof_monitores'].astype('int64')
eb = eb.apply(preencher_limitantes, axis=1)

# ajustando variaveis categoricas
eb['co_regiao'] = eb['co_regiao'].astype('category')
eb['co_uf'] = eb['co_uf'].astype('category')
eb['co_municipio'] = eb['co_municipio'].astype('category')
eb['co_mesorregiao'] = eb['co_mesorregiao'].astype('category')
eb['co_microrregiao'] = eb['co_microrregiao'].astype('category')
eb['co_distrito'] = eb['co_distrito'].astype('category')
eb['in_esp_ce'] = eb['in_esp_ce'].replace(yn).astype('category')
eb['in_periodos_semestrais'] = eb['in_periodos_semestrais'].replace(yn).astype('category')
eb['in_esp'] = eb['in_esp'].replace(yn).astype('category')
eb['in_eja_med'] = eb['in_eja_med'].replace(yn).astype('category')
eb['in_eja_fund'] = eb['in_eja_fund'].replace(yn).astype('category')
eb['in_eja'] = eb['in_eja'].replace(yn).astype('category')
eb['in_prof_tec'] = eb['in_prof_tec'].replace(yn).astype('category')
eb['in_esp_cc'] = eb['in_esp_cc'].replace(yn).astype('category')
eb['in_prof'] = eb['in_prof'].replace(yn).astype('category')
eb['in_med'] = eb['in_med'].replace(yn).astype('category')
eb['in_fund_af'] = eb['in_fund_af'].replace(yn).astype('category')
eb['in_fund'] = eb['in_fund'].replace(yn).astype('category')
eb['in_inf_pre'] = eb['in_inf_pre'].replace(yn).astype('category')
eb['in_inf_cre'] = eb['in_inf_cre'].replace(yn).astype('category')
eb['in_inf'] = eb['in_inf'].replace(yn).astype('category')
eb['in_bas'] = eb['in_bas'].replace(yn).astype('category')
eb['in_ead'] = eb['in_ead'].replace(yn).astype('category')
eb['in_noturno'] = eb['in_noturno'].replace(yn).astype('category')
eb['in_diurno'] = eb['in_diurno'].replace(yn).astype('category')
eb['in_formacao_alternancia'] = eb['in_formacao_alternancia'].replace(yn).astype('category')
eb['in_modulos'] = eb['in_modulos'].replace(yn).astype('category')
eb['in_grupos_nao_seriados'] = eb['in_grupos_nao_seriados'].replace(yn).astype('category')
eb['in_fundamental_ciclos'] = eb['in_fundamental_ciclos'].replace(yn).astype('category')
eb['in_fund_ai'] = eb['in_fund_ai'].replace(yn).astype('category')
eb['in_serie_ano'] = eb['in_serie_ano'].replace(yn).astype('category')
eb['in_predio_compartilhado'] = eb['in_predio_compartilhado'].replace(yn).astype('category')
eb['in_banda_larga'] = eb['in_banda_larga'].replace(yn).astype('category')
eb['in_reserva_nenhuma'] = eb['in_reserva_nenhuma'].replace(yn).astype('category')
eb['in_reserva_outros'] = eb['in_reserva_outros'].replace(yn).astype('category')
eb['in_reserva_pcd'] = eb['in_reserva_pcd'].replace(yn).astype('category')
eb['in_reserva_publica'] = eb['in_reserva_publica'].replace(yn).astype('category')
eb['in_reserva_renda'] = eb['in_reserva_renda'].replace(yn).astype('category')
eb['in_mant_escola_privada_sind'] = eb['in_mant_escola_privada_sind'].replace(yn).astype('category')
eb['in_conveniada_pp'] = eb['in_conveniada_pp'].replace(yn).astype('category')
eb['in_mant_escola_privada_sist_s'] = eb['in_mant_escola_privada_sist_s'].replace(yn).astype('category')
eb['in_mant_escola_priv_ong_oscip'] = eb['in_mant_escola_priv_ong_oscip'].replace(yn).astype('category')
eb['in_mant_escola_privada_oscip'] = eb['in_mant_escola_privada_oscip'].replace(yn).astype('category')
eb['in_mant_escola_privada_ong'] = eb['in_mant_escola_privada_ong'].replace(yn).astype('category')
eb['in_mant_escola_privada_emp'] = eb['in_mant_escola_privada_emp'].replace(yn).astype('category')
eb['in_mant_escola_privada_s_fins'] = eb['in_mant_escola_privada_s_fins'].replace(yn).astype('category')
eb['in_reserva_ppi'] = eb['in_reserva_ppi'].replace(yn).astype('category')
eb['in_vinculo_secretaria_educacao'] = eb['in_vinculo_secretaria_educacao'].replace(yn).astype('category')
eb['in_vinculo_outro_orgao'] = eb['in_vinculo_outro_orgao'].replace(yn).astype('category')
eb['in_vinculo_secretaria_saude'] = eb['in_vinculo_secretaria_saude'].replace(yn).astype('category')
eb['in_vinculo_seguranca_publica'] = eb['in_vinculo_seguranca_publica'].replace(yn).astype('category')
eb['in_local_func_predio_escolar'] = eb['in_local_func_predio_escolar'].replace(yn).astype('category')
eb['in_local_func_socioeducativo'] = eb['in_local_func_socioeducativo'].replace(yn).astype('category')
eb['in_local_func_unid_prisional'] = eb['in_local_func_unid_prisional'].replace(yn).astype('category')
eb['in_local_func_prisional_socio'] = eb['in_local_func_prisional_socio'].replace(yn).astype('category')
eb['in_local_func_galpao'] = eb['in_local_func_galpao'].replace(yn).astype('category')
eb['in_local_func_salas_outra_esc'] = eb['in_local_func_salas_outra_esc'].replace(yn).astype('category')
eb['in_local_func_outros'] = eb['in_local_func_outros'].replace(yn).astype('category')
eb['in_agua_potavel'] = eb['in_agua_potavel'].replace(yn).astype('category')
eb['in_energia_rede_publica'] = eb['in_energia_rede_publica'].replace(yn).astype('category')
eb['in_esgoto_rede_publica'] = eb['in_esgoto_rede_publica'].replace(yn).astype('category')
eb['in_almoxarifado'] = eb['in_almoxarifado'].replace(yn).astype('category')
eb['in_area_verde'] = eb['in_area_verde'].replace(yn).astype('category')
eb['in_auditorio'] = eb['in_auditorio'].replace(yn).astype('category')
eb['in_banheiro'] = eb['in_banheiro'].replace(yn).astype('category')
eb['in_banheiro_funcionarios'] = eb['in_banheiro_funcionarios'].replace(yn).astype('category')
eb['in_banheiro_chuveiro'] = eb['in_banheiro_chuveiro'].replace(yn).astype('category')
eb['in_biblioteca'] = eb['in_biblioteca'].replace(yn).astype('category')
eb['in_biblioteca_sala_leitura'] = eb['in_biblioteca_sala_leitura'].replace(yn).astype('category')
eb['in_cozinha'] = eb['in_cozinha'].replace(yn).astype('category')
eb['in_dormitorio_aluno'] = eb['in_dormitorio_aluno'].replace(yn).astype('category')
eb['in_dormitorio_professor'] = eb['in_dormitorio_professor'].replace(yn).astype('category')
eb['in_laboratorio_ciencias'] = eb['in_laboratorio_ciencias'].replace(yn).astype('category')
eb['in_laboratorio_informatica'] = eb['in_laboratorio_informatica'].replace(yn).astype('category')
eb['in_parque_infantil'] = eb['in_parque_infantil'].replace(yn).astype('category')
eb['in_piscina'] = eb['in_piscina'].replace(yn).astype('category')
eb['in_quadra_esportes'] = eb['in_quadra_esportes'].replace(yn).astype('category')
eb['in_refeitorio'] = eb['in_refeitorio'].replace(yn).astype('category')
eb['in_sala_atelie_artes'] = eb['in_sala_atelie_artes'].replace(yn).astype('category')
eb['in_sala_musica_coral'] = eb['in_sala_musica_coral'].replace(yn).astype('category')
eb['in_sala_estudio_danca'] = eb['in_sala_estudio_danca'].replace(yn).astype('category')
eb['in_sala_multiuso'] = eb['in_sala_multiuso'].replace(yn).astype('category')
eb['in_sala_diretoria'] = eb['in_sala_diretoria'].replace(yn).astype('category')
eb['in_sala_leitura'] = eb['in_sala_leitura'].replace(yn).astype('category')
eb['in_sala_professor'] = eb['in_sala_professor'].replace(yn).astype('category')
eb['in_sala_repouso_aluno'] = eb['in_sala_repouso_aluno'].replace(yn).astype('category')
eb['in_secretaria'] = eb['in_secretaria'].replace(yn).astype('category')
eb['in_terreirao'] = eb['in_terreirao'].replace(yn).astype('category')
eb['in_viveiro'] = eb['in_viveiro'].replace(yn).astype('category')
eb['in_dependencias_outras'] = eb['in_dependencias_outras'].replace(yn).astype('category')
eb['in_equip_scanner'] = eb['in_equip_scanner'].replace(yn).astype('category')
eb['in_internet'] = eb['in_internet'].replace(yn).astype('category')
eb['in_internet_alunos'] = eb['in_internet_alunos'].replace(yn).astype('category')
eb['in_internet_administrativo'] = eb['in_internet_administrativo'].replace(yn).astype('category')
eb['in_internet_aprendizagem'] = eb['in_internet_aprendizagem'].replace(yn).astype('category')
eb['in_internet_comunidade'] = eb['in_internet_comunidade'].replace(yn).astype('category')
eb['in_acesso_internet_computador'] = eb['in_acesso_internet_computador'].replace(yn).astype('category')
eb['in_aces_internet_disp_pessoais'] = eb['in_aces_internet_disp_pessoais'].replace(yn).astype('category')
eb['in_alimentacao'] = eb['in_alimentacao'].replace(yn).astype('category')
eb['in_material_ped_multimidia'] = eb['in_material_ped_multimidia'].replace(yn).astype('category')
eb['in_material_ped_infantil'] = eb['in_material_ped_infantil'].replace(yn).astype('category')
eb['in_material_ped_cientifico'] = eb['in_material_ped_cientifico'].replace(yn).astype('category')
eb['in_material_ped_difusao'] = eb['in_material_ped_difusao'].replace(yn).astype('category')
eb['in_material_ped_musical'] = eb['in_material_ped_musical'].replace(yn).astype('category')
eb['in_material_ped_jogos'] = eb['in_material_ped_jogos'].replace(yn).astype('category')
eb['in_material_ped_artisticas'] = eb['in_material_ped_artisticas'].replace(yn).astype('category')
eb['in_material_ped_desportiva'] = eb['in_material_ped_desportiva'].replace(yn).astype('category')
eb['in_material_ped_indigena'] = eb['in_material_ped_indigena'].replace(yn).astype('category')
eb['in_material_ped_etnico'] = eb['in_material_ped_etnico'].replace(yn).astype('category')
eb['in_material_ped_campo'] = eb['in_material_ped_campo'].replace(yn).astype('category')
eb['in_educacao_indigena'] = eb['in_educacao_indigena'].replace(yn).astype('category')
eb['in_exame_selecao'] = eb['in_exame_selecao'].replace(yn).astype('category')
eb['in_redes_sociais'] = eb['in_redes_sociais'].replace(yn).astype('category')
eb['in_espaco_atividade'] = eb['in_espaco_atividade'].replace(yn).astype('category')
eb['in_espaco_equipamento'] = eb['in_espaco_equipamento'].replace(yn).astype('category')
eb['in_orgao_ass_pais'] = eb['in_orgao_ass_pais'].replace(yn).astype('category')
eb['in_orgao_ass_pais_mestres'] = eb['in_orgao_ass_pais_mestres'].replace(yn).astype('category')
eb['in_orgao_conselho_escolar'] = eb['in_orgao_conselho_escolar'].replace(yn).astype('category')
eb['in_orgao_gremio_estudantil'] = eb['in_orgao_gremio_estudantil'].replace(yn).astype('category')
eb['in_orgao_outros'] = eb['in_orgao_outros'].replace(yn).astype('category')
eb['in_orgao_nenhum'] = eb['in_orgao_nenhum'].replace(yn).astype('category')
eb['tp_dependencia'] = eb['tp_dependencia'].replace({1:'federal',2:'estadual', 3:'municipal', 4:'privada'}).astype('category')
eb['tp_localizacao'] = eb['tp_localizacao'].replace({1:'urbana',2:'rural'}).astype('category')
eb['tp_localizacao_diferenciada'] = eb['tp_localizacao_diferenciada'].replace({0:'normal', 1:'assentamento',2:'indigena', 3:'quilombo'}).astype('category')
eb['tp_categoria_escola_privada'] = eb['tp_categoria_escola_privada'].replace({
    np.nan:'publica', 1:'particular', 2:'comunitaria', 3:'confessional', 4:'filantropica'}).astype('category')
eb['tp_ocupacao_predio_escolar'] = eb['tp_ocupacao_predio_escolar'].replace({
    np.nan:'sem ocupacao', 1:'proprio', 2:'alugado', 3:'cedido'}).astype('category')
eb['tp_ocupacao_galpao'] = eb['tp_ocupacao_galpao'].replace({
    np.nan:'sem galpao', 9:'sem galpao', 1:'proprio', 2:'alugado', 3:'cedido'}).astype('category')
eb['tp_lingua'] = eb['tp_indigena_lingua'].replace({
    np.nan:'portugues', 1:'portugues', 2:'indigena', 3:'ambos'}).astype('category')
eb['tp_convenio_poder_publico'] = eb['tp_convenio_poder_publico'].replace({
    np.nan:'sem convenio', 1:'municipal', 2:'estadual', 3:'ambos'}).astype('category')
eb['tp_rede_local'] = eb['tp_rede_local'].replace({
    1:'a cabo', 2:'wireless', 3:'ambos', 9:'sem internet'}).astype('category')


eb.drop(columns=['tp_situacao_funcionamento','tp_indigena_lingua'], inplace=True)
ed_basica_df = eb.set_index('co_entidade', drop=True)
ed_basica_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182460 entries, 11022558 to 53086007
# Columns: 174 entries, co_regiao to tp_lingua
# dtypes: category(130), int64(43), object(1)
# memory usage: 86.5+ MB

# %%
any(ed_basica_df.isna().sum() > 0)
# Out:
# False

# %% [markdown]
# ---
# ## Notas ENEM ##

# %%
# lendo dataframe
enem_df = pd.read_csv('../dados/NOTA_ENEM_2019_ESCOLA.csv', header=0, usecols=[1, 13], names=['cod inep','nota enem'], dtype={'cod inep':np.int64, 'nota enem':np.float64})

# configurando codigo da escola como indice
enem_df.set_index('cod inep', drop=True, inplace=True)
enem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19598 entries, 23246847 to 23071265
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nota enem  19598 non-null  float64
# dtypes: float64(1)
# memory usage: 306.2 KB

# %% [markdown]
# ---
# ## Juntando datasets ##

# %%
final_df = ed_basica_df.join(atu_df,how='inner')
final_df = final_df.join(ied_df,how='inner')
final_df = final_df.join(tdi_df,how='inner')
final_df = final_df.join(had_df,how='inner')
final_df = final_df.join(inse_df,how='left')
final_df = final_df.join(tre_df,how='inner')
final_df = final_df.join(enem_df,how='inner')

# %%
final_df.corr()['nota enem'].sort_values(ascending=False)
# Out:
# nota enem                        1.000000
# valor inse                       0.620039
# qt_salas_utilizadas              0.417246
# qt_equip_multimidia              0.415716
# perc aprovado                    0.395189
# qt_salas_utiliza_climatizadas    0.374802
# qt_equip_som                     0.309231
# qt_desktop_aluno                 0.274120
# perc doc3                        0.250484
# media hora-aula diaria           0.203973
# qt_equip_lousa_digital           0.197878
# qt_prof_nutricionista            0.180739
# qt_equip_tv                      0.167935
# qt_comp_portatil_aluno           0.156574
# qt_equip_dvd                     0.155418
# qt_prof_secretario               0.149395
# qt_tablet_aluno                  0.141091
# qt_tur_prof_tec                  0.133754
# qt_tur_prof                      0.133005
# perc doc2                        0.132754
# qt_prof_fonaudiologo             0.113799
# qt_prof_saude                    0.104947
# ...

# %%
final_df.corr()['nota enem'].sort_values(ascending=False)[:10]
# Out:
# nota enem                        1.000000
# valor inse                       0.620039
# qt_salas_utilizadas              0.417246
# qt_equip_multimidia              0.415716
# perc aprovado                    0.395189
# qt_salas_utiliza_climatizadas    0.374802
# qt_equip_som                     0.309231
# qt_desktop_aluno                 0.274120
# perc doc3                        0.250484
# media hora-aula diaria           0.203973
# Name: nota enem, dtype: float64

# %%
sns.set_palette('bone_r')
sns.scatterplot(data=final_df, x='valor inse', y='nota enem', hue='co_regiao')
plt.show()

# %%
final_df.to_csv('dados/final.csv')
