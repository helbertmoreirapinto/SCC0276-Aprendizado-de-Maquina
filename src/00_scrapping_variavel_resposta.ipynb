# %%
import time
import pandas as pd
import json

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager

# %%
__LOADING_PAGE_TIME__ = 3
options = Options()
options.headless = False
url = 'https://enem2019.evolucional.com.br/RD.html'

media_colegio = pd.DataFrame()

# %%
#Carrega pagina da web
browser = webdriver.Chrome(ChromeDriverManager().install(), options=options)
browser.get(url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Driver [C:\Users\helbe\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache

# %%
# configurar para pegar 100 registros por vez
time.sleep(__LOADING_PAGE_TIME__)
combo = browser.find_elements_by_name('example_length')[0]
combo.click()
combo.send_keys(Keys.DOWN)
combo.send_keys(Keys.ENTER)

# %%
for i in range(196):
    time.sleep(__LOADING_PAGE_TIME__)
    conteudo = browser.find_elements_by_id('example')[0]
    html_conteudo = conteudo.get_attribute('outerHTML')

    table = BeautifulSoup(html_conteudo, 'html.parser').find(name='table')
    df = pd.read_html(str(table))[0]
    media_colegio = media_colegio.append(df).reset_index(drop=True)
    if i % 15 == 0:
        print(len(media_colegio))

    bt_prox = browser.find_elements_by_id('example_next')[0]
    bt_prox.click()
media_colegio.set_index('Posição',drop=True,inplace=True)
# Out:
# 100
# 1600
# 3100
# 4600
# 6100
# 7600
# 9100
# 10600
# 12100
# 13600
# 15100
# 16600
# 18100
# 19598

# %%
media_colegio
# Out:
#          Código INEP                                             Escola  \
# Posição
# 1           23246847                  FARIAS BRITO COLEGIO DE APLICACAO
# 2           23246871     ARI DE SA CAVALCANTE SEDE MARIO MAMEDE COLEGIO
# 3           31350664                                  COLEGIO BERNOULLI
# 4           35399197                         OBJETIVO COLEGIO INTEGRADO
# 5           31349720                                  FIBONACCI COLEGIO
# ...              ...                                                ...
# 19594       17029341                        ESCOLA INDIGENA 19 DE ABRIL
# 19595       21076855                     CENTRO DE ENSINO NAGIB HAICKEL
# 19596       13252208  ESC EST INDIGENA PROFESSOR GILDO SAMPAIO MEGAT...
# 19597       13008196                ESCOLA ESTADUAL ALMIRANTE TAMANDARE
# 19598       23071265           INSTITUTO CEARENSE DE EDUCACAO DE SURDOS
#
#                Estado             Cidade Dependência administrativa  \
# Posição
# 1               Ceará          Fortaleza                    Privada
# 2               Ceará          Fortaleza                    Privada
# 3        Minas Gerais     Belo Horizonte                    Privada
# 4           São Paulo          São Paulo                    Privada
# 5        Minas Gerais           Ipatinga                    Privada
# ...               ...                ...                        ...
# 19594       Tocantins           Goiatins                   Estadual
# 19595        Maranhão      Pindaré Mirim                   Estadual
# 19596        Amazonas  Benjamin Constant                   Estadual
# 19597        Amazonas          Tabatinga                   Estadual
# 19598           Ceará          Fortaleza                   Estadual
#
#         Localização  Alunos      CH      CN      LC      MT      RD   Média
# Posição
# 1            Urbana      35  692.85  674.50  652.24  845.89  935.43  760.18
# 2            Urbana      33  695.67  676.34  652.91  836.65  915.15  755.34
# 3            Urbana     280  681.58  668.20  634.47  823.80  906.64  742.94
# 4            Urbana      53  677.45  682.90  638.72  836.11  868.68  740.77
# 5            Urbana      57  666.41  657.87  630.84  809.55  938.95  740.72
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# 19594         Rural      10  423.49  412.24  386.12  449.16  284.00  391.00
# 19595        Urbana      16  439.87  409.58  431.09  411.73  261.25  390.70
# 19596         Rural      56  422.24  407.61  411.16  425.47  241.79  381.65
# 19597         Rural      21  432.40  405.50  377.89  441.75  154.29  362.36
# 19598        Urbana      18  421.57  414.88  406.04  420.93  138.89  360.46
#
# [19598 rows x 13 columns]

# %%
media_colegio.to_csv('ESCOLA_ENEM_2019.csv')
