# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
base = pd.read_csv('dados/final.csv', index_col=0)
base.head()
# Out:
#           co_regiao  co_uf  co_municipio  co_mesorregiao  co_microrregiao  \
# 11024968          1     11       1100015            1102            11006
# 11025638          1     11       1100015            1102            11006
# 11006773          1     11       1100023            1102            11003
# 11006889          1     11       1100023            1102            11003
# 11007168          1     11       1100023            1102            11003
#
#                                                no_entidade tp_dependencia  \
# 11024968           EEEMTI JUSCELINO KUBITSCHEK DE OLIVEIRA       estadual
# 11025638                        EEEFM PADRE EZEQUIEL RAMIN       estadual
# 11006773                               EEEFM CORA CORALINA       estadual
# 11006889                             EEEFM ANISIO TEIXEIRA       estadual
# 11007168  COLEGIO TIRADENTES DA POLICIA MILITAR - CTPM III       estadual
#
#          tp_categoria_escola_privada tp_localizacao  \
# 11024968                     publica         urbana
# 11025638                     publica         urbana
# 11006773                     publica         urbana
# 11006889                     publica         urbana
# 11007168                     publica         urbana
#
#          tp_localizacao_diferenciada  ... perc doc4 perc doc5 perc doc6  \
# 11024968                      normal  ...      13.3       6.7       0.0
# 11025638                      normal  ...      43.9      34.1      22.0
# 11006773                      normal  ...      68.8      15.6      12.5
# 11006889                      normal  ...      57.1      37.1       2.9
# 11007168                      normal  ...      63.1      31.6       5.3
#
#          taxa distorcao idade serie media hora-aula diaria valor inse  \
# 11024968                        9.1                    9.5       4.78
# 11025638                       28.4                    3.9       4.76
# 11006773                       34.3                    3.6       4.88
# 11006889                       43.7                    3.6       4.60
# 11007168                       27.1                    4.0       4.79
#
#          perc aprovado perc reprovado perc evasao nota enem
# 11024968          97.7            2.3         0.0    539.94
# 11025638          91.4            0.5         8.1    485.33
# 11006773          68.0           16.3        15.7    479.49
# 11006889          70.3            4.8        24.9    468.94
# 11007168          88.2            8.6         3.2    482.38
#
# [5 rows x 187 columns]

# %%
fig = plt.figure(figsize=(15,8))
fig.suptitle('Notas do ENEM por escola')
sns.set_palette('viridis')
sns.displot(data=base, x='nota enem', hue='tp_dependencia', col='tp_localizacao', kind='hist')

plt.show()
